# %% [markdown]
# <a href="https://colab.research.google.com/github/AjayRahulRaja/data-mining-and-discovery/blob/main/SQL_assignemnt_Data_mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# required imports
import numpy as np
import pandas as pd
import random

# %% [markdown]
# *** Genre Table: Data Generation ***

# %%
count = np.arange(1, 1087)

# List of all Genres
genreList = ['Action', 'Romance', 'Western', 'Comedy', 'War', 'Periodic', 'Drama', 'Thriller', 'Horror']
# List of all movie names
movieNameList = movieNameList = [
    'Boyhood', 'Juno', 'Rocky', 'Rush', 'Crash', 'Amélie', 'Fargo', 'Argo', 'Her', 'Doubt', 'Babel', 'Moon', 'Ray', 'Mud', 'Lucy',
    'Hostel', 'Fury', 'Chef', 'Brick', 'Drive', 'Ghost', 'Grease', 'Giant', 'Gilda', 'Clue', 'Dumbo', 'Hitch', 'Signs', 'Se7en',
    'Heat', 'Speed', 'Big', 'Taken', 'Hook', 'Shaft', 'Congo', 'Twins', 'Holes', 'Alive', 'Pi', 'Fear', 'Rudy', 'Milk', 'Troy',
    'Red', 'MIB', 'Epic', 'Ali', 'Ted', 'Coco', 'Hugo', 'It', 'Up', 'Sing', 'Bolt', 'Dune', 'Wit', 'Fire', 'Jobs', 'Amour', 'Rush',
    'Ray', 'Liar', 'Duel', 'Ed', 'Spy', 'Babe', 'Shrek', 'Cube', 'Rio', 'Salt', 'Jaws', 'Election', 'Abyss', 'Legend', 'Oceans',
    'Freaky', 'Unknown', 'Epic', 'Rango', 'Nine', 'Crash', 'Eraser', 'Witch', 'Whale', 'Fearless', 'Poltergeist', 'Panic', 'Omen',
    'Silent', 'Misery', 'Parasite', 'Joker', 'Gravity', 'Creep', 'Titanic', 'Frozen', 'Bambi', 'Orphan', 'Hero', 'Kick-Ass',
    'Sinister', 'Bound', 'Snatch', 'Glory', 'Castaway', 'Bully', 'Tootsie', 'Drive', 'Friday', 'Wanted', 'Waitress', 'Saw', 'Rudy',
    'Blow', 'Dune', 'Foxcatcher', 'Chappie', 'Jobs', 'Maleficent', 'Rogue', 'Deadpool', 'Carrie', 'Hop', 'Benji', 'Bolt', 'Pride',
    'Frozen', 'Insidious', 'Truth', 'Lincoln', 'Annie', 'Hercules', 'Rio', 'Gold', 'Moonlight', 'Logan', 'Wonder', 'Alien', 'Sideways',
    'Abyss', 'Stuck', 'Blue', 'Beast', 'Max', 'Solo', 'Birdman', 'Nine', 'Babel', 'Milk', 'The Net', 'Cube', 'Lion', 'Closer', 'Soul',
    'The Witch', 'Lost', 'Closer', 'Brick', 'Mud', 'Drive', 'Blow', 'Rudy', 'Milk', 'Speed', 'Alive', 'Fear', 'Ted', 'Gone', 'Epic',
    'Bolt', 'Jobs', 'Epic', 'Doubt', 'Signs', 'Nine', 'Speed', 'Milk', 'Sideways', 'Hook', 'Alive', 'Jobs', 'Gone', 'Gone', 'Coco',
    'Holes', 'Ali', 'Pi', 'Se7en', 'Gone', 'Up', 'Fear', 'Whale', 'Milk', 'Rush', 'Signs', 'Red', 'Fear', 'Signs', 'Fear', 'Gone',
    'Ray', 'Gone', 'Fear', 'Gone', 'Luca', 'Lion', 'Panic', 'Shrek', 'Bolt', 'Signs', 'Epic', 'Holes', 'The Net', 'Rush', 'Omen',
    'Creep', 'Legend', 'Nine', 'Holes', 'It', 'Rango', 'Grease', 'Speed', 'Signs', 'Ray', 'Liar', 'Epic', 'Nine', 'Rango', 'Ali',
    'Panic', 'Fear', 'Nine', 'Signs', 'Lion', 'Ted', 'Gone', 'Signs', 'Creep', 'Fear', 'Hero', 'Bully', 'Rango', 'Hook', 'Speed',
    'Rush', 'Freaky', 'Legend', 'Gone', 'Rango', 'Ali', 'Panic', 'Signs', 'Hero', 'Juno', 'Rush', 'Milk', 'Legend', 'Lost', 'Nine',
    'Abyss', 'Gone', 'Signs', 'Fear', 'Gone', 'Milk', 'Epic', 'Gone', 'Nine', 'Red', 'Jobs', 'Coco', 'Signs', 'Rango', 'Nine',
    'Fear', 'Ray', 'Gone', 'Fear', 'Epic', 'Omen', 'Fear', 'The Net', 'Fear', 'Gone', 'Milk', 'Fear', 'Milk', 'Rudy', 'Gone', 'Jobs',
    'Gone', 'Fear', 'Fear', 'Red', 'Jobs', 'Signs', 'Epic', 'Nine', 'Hero', 'Fear', 'Nine', 'Signs', 'Gone', 'Jobs', 'Gone', 'Milk',
    'Signs', 'Signs', 'Epic', 'Nine', 'Fear', 'Nine', 'Signs', 'Milk', 'Fear', 'The Net', 'Epic', 'Hero', 'Fear', 'Nine', 'Signs',
    'Signs', 'Gone', 'Fear', 'Hero', 'Milk', 'Epic', 'Nine', 'Gone', 'Fear', 'Gone', 'Signs', 'Gone', 'Hero', 'Gone', 'Gone', 'The Net',
    'Fear', 'Milk', 'Gone', 'Nine', 'Epic', 'Fear', 'Nine', 'Gone', 'Fear', 'Gone', 'Fear', 'Gone', 'The Net', 'Fear', 'Nine',
    'Milk', 'Hero', 'Nine', 'Fear', 'Epic', 'Nine', 'Gone', 'Fear', 'Milk', 'The Net', 'Epic', 'Hero', 'Fear', 'Nine', 'Milk', 'Fear',
    'Gone', 'Signs', 'Gone', 'Nine', 'Gone', 'Fear', 'Epic', 'Gone', 'Hero', 'The Net', 'Gone', 'Epic', 'Fear', 'Gone', 'Milk', 'Fear',
    'Gone', 'Nine', 'Milk', 'Epic', 'Hero', 'Nine', 'Gone', 'Fear', 'Nine', 'Fear', 'Gone', 'Epic', 'Hero', 'Fear', 'Epic', 'Fear',
    'Gone', 'Milk', 'Gone', 'Nine', 'Fear', 'Epic', 'Gone', 'Hero', 'Nine', 'Fear', 'Nine', 'Fear', 'Gone', 'Epic', 'Gone', 'Hero',
    'The Net', 'Milk', 'Nine', 'Hero', 'Gone', 'Epic', 'Fear', 'Nine', 'Epic', 'Hero', 'Nine', 'Gone', 'Epic', 'Nine', 'Fear', 'Milk',
    'Epic', 'Nine', 'Epic', 'Nine', 'Hero', 'Nine', 'Gone', 'Fear', 'Milk', 'Epic', 'Hero', 'Nine', 'Gone', 'Fear', 'Nine', 'Epic',
    'Hero', 'Gone', 'Nine', 'Epic', 'Nine', 'Hero', 'Nine', 'Gone', 'Epic', 'Nine', 'Fear', 'Milk', 'Hero', 'Gone', 'Fear', 'Gone',
    'Epic', 'Gone', 'Nine', 'Hero', 'Nine', 'Fear', 'Epic', 'Nine', 'Epic', 'Fear', 'Hero', 'Milk', 'Nine', 'Hero', 'Gone', 'Fear',
    'Gone', 'Fear', 'Nine', 'Epic', 'Gone', 'Nine', 'Epic', 'Hero', 'Nine', 'Fear', 'Nine', 'Epic', 'Nine', 'Fear', 'Gone', 'Nine',
    'Epic', 'Nine', 'Fear', 'Hero', 'Nine', 'Epic', 'Nine', 'Gone', 'Fear', 'Hero', 'Epic', 'Nine', 'Hero', 'Nine', 'Gone', 'Hero',
    'Epic', 'Gone', 'Nine', 'Fear', 'Epic', 'Nine', 'Gone', 'Fear', 'Nine', 'Fear', 'Epic', 'Nine', 'Hero', 'Gone', 'Epic', 'Nine',
    'Epic', 'Gone', 'Nine', 'Gone', 'Hero', 'Nine', 'Fear', 'Gone', 'Nine', 'Epic', 'Nine', 'Epic', 'Hero', 'Nine', 'Fear', 'Gone',
    'Epic', 'Hero', 'Gone', 'Nine', 'Epic', 'Hero', 'Nine', 'Gone', 'Hero', 'Nine', 'Gone', 'Epic', 'Nine', 'Epic', 'Nine', 'Gone',
    'Hero', 'Nine', 'Epic', 'Nine', 'Fear', 'Gone', 'Nine', 'Hero', 'Nine', 'Gone', 'Nine', 'Hero', 'Nine', 'Epic', 'Gone', 'Nine',
    'Fear', 'Hero', 'Nine', 'Gone', 'Nine', 'Fear', 'Hero', 'Nine', 'Gone', 'Nine', 'Gone', 'Hero', 'Nine', 'Epic', 'Nine', 'Fear',
    'Gladiator', 'Inception', 'Memento', 'Clerks', 'Glory', 'Crashers', 'Superbad', 'Twilight', 'Sunshine', 'Gravity', 'Zodiac',
    'Looper', 'Fences', 'Sully', 'Enigma', 'Speedway', 'Loving', 'Saboteur', 'Malcolm', 'Kickboxer', 'Punchline', 'Gigantic',
    'Clash', 'Valhalla', 'Bliss', 'Limitless', 'Frozen', 'Ray', 'Rogue', 'Hamlet', 'Bound', 'Hopscotch', 'Takers', 'Powder',
    'Passengers', 'Breakdown', 'Swades', 'Stealth', 'Insomnia', 'Interstellar', 'Arrival', 'Slapshot', 'Firestorm', 'Elvira',
    'Battleship', 'Carrie', 'Unstoppable', 'Valkyrie', 'Rebound', 'Screamers', 'Spectrum', 'Pandemic', 'Drumline', 'Sideways',
    'Shrink', 'Serendipity', 'Surrogates', 'Speedster', 'Mystic', 'Whiplash', 'Mystery', 'Contagion', 'Revolution', 'Draft',
    'Rambo', 'Icarus', 'Inferno', 'Aftermath', 'Megamind', 'Equalizer', 'Trolls', 'Freaks', 'Spectre', 'Preacher', 'Freefall',
    'Memento', 'Valentine', 'Ninja', 'Dreamers', 'Exodus', 'Dante', 'Gigantic', 'Heavenly', 'Crimson', 'Venom', 'Pursuit',
    'Pitch', 'Risen', 'Beowulf', 'Divergent', 'Chinatown', 'Annihilation', 'Gamer', 'Vanilla', 'Highlander', 'Bullet',
    'Shattered', 'Equilibrium', 'Deceiver', 'Scarface', 'Witness', 'Detour', 'Atonement', 'Legendary', 'Cradle', 'Dogville',
    'Damascus', 'Winter', 'Children', 'Disorder', 'Goldfinger', 'Turncoat', 'Warriors', 'Immortal', 'Oblivion', 'Bleed',
    'Narc', 'Contraband', 'Blowout', 'Inside', 'Downfall', 'Infernal', 'Replicant', 'Rampage', 'Barbarella', 'Predator',
    'Bloodsport', 'Starman', 'Leverage', 'Bone', 'Fortress', 'Hanna', 'Hancock', 'Poseidon', 'Darkness', 'Gamer', 'Brothers',
    'Ironclad', 'Wavelength', 'Stalker', 'Blackhat', 'Tequila', 'Dominion', 'Intruder', 'Witnesses', 'Relic', 'Takedown',
    'Vengeance', 'Intruders', 'Prisoners', 'Knockout', 'Justice', 'Savage', 'Parasite', 'Allegiant', 'Runaway', 'Protector',
    'Subway', 'Sunrise', 'Prime', 'Crossing', 'Street', 'Freaky', 'Ghostbusters', 'Dredd', 'Hostile', 'Contender', 'Brick',
    'Darkman', 'Moonrise', 'Thriller', 'Ginger', 'Blackjack', 'Redemption', 'Skyline', 'Conspiracy', 'Chappie', 'Cyber',
    'Nemesis', 'District', 'Messenger', 'Underdog', 'Whiteout', 'Collide', 'Afterlife', 'Vengeance', 'Aftershock', 'Escobar',
    'Champion', 'Firstborn', 'Encounter', 'Extract', 'Legend', 'Sabotage', 'Lockdown', 'Centurion', 'Cannonball', 'Escape',
    'Warcraft', 'Bushwick', 'Skyscraper', 'Assassin', 'Breakout', 'Shotgun', 'MacGruber', 'Convoy', 'Extremity', 'Vortex',
    'Blackwood', 'Redemption', 'Desperado', 'Champion', 'Lazarus', 'Conqueror', 'Coldplay', 'Lockout', 'Aftermath', 'Beast',
    'Kingpin', 'Amistad', 'Dreamscape', 'Velocity', 'Invisible', 'Ghostwriter', 'Epidemic', 'Brawler', 'Crashpoint', 'Zookeeper',
    'Pathfinder', 'Backdraft', 'Fireproof', 'Invasion', 'Firebirds', 'Stealth', 'Kingsman', 'Erasure', 'Ramparts', 'Invincible',
    'Snowpiercer', 'Kickboxer', 'Casablanca', 'Shutter', 'Looper', 'Untouchables', 'Machete', 'Snowden', 'Brawl', 'Templar',
    'Outpost', 'Slasher', 'Rushmore', 'Untraceable', 'Feedback', 'Darklands', 'Crypt', 'Holocaust', 'Deepwater', 'Extract',
    'Adrenaline', 'Counterpart', 'Cyclone', 'Snitch', 'Trapped', 'Mechanic', 'Deathrace', 'Longshot', 'Whitehouse', 'Prophecy',
    'Honey', 'Armageddon', 'Serpent', 'Hellraiser', 'Heroine', 'Phoenix', 'Rebel', 'Hercules', 'Pulp', 'Skywalker', 'Anomaly',
    'Embassy', 'Revolt', 'Fury', 'Primeval', 'Overboard', 'Goldstone', 'Afterglow', 'Genesis', 'Thelma', 'Submarine', 'Bordertown',
    'Dredd', 'Ambulance', 'Flashback', 'Fearless', 'Collision', 'Brightburn', 'Instinct', 'Interceptor', 'Nightmare', 'Underworld',
    'Daybreak', 'Emporium', 'Coraline', 'Popstar', 'Dragonslayer', 'Wonderland', 'Moonraker', 'Viceroy', 'Cocoon', 'Experiment',
    'Ravager', 'Honeytrap', 'Knighthood', 'Overtime', 'Dreamworld', 'Freedom', 'Clover', 'Witnesses', 'Starbright', 'Quicksand',
    'Afterparty', 'Blackbox', 'Countdown', 'Overdrive', 'Sparkle', 'Gorilla', 'Foxfire', 'Sunflower', 'Voyagers', 'Caligula',
    'Union', 'Network', 'Nightmare', 'Shame', 'Brokeback', 'District', 'Lawless', 'Firelight', 'Lowdown', 'Peacemaker', 'Mercy',
    'Escapade', 'Darkwing', 'Fiasco', 'Masquerade', 'Machinations', 'Sanctum', 'Sinister', 'Redline', 'Supernova', 'Paranoid',
    'Truecrime', 'Creepshow', 'Vigilante', 'Mother', 'Cellblock', 'Skyfire', 'Stormbreaker', 'Fortress', 'Showtime', 'Ascension',
    'Infestation', 'Blacklight', 'Necropolis', 'Fulltime', 'Aftershock', 'Chocolat', 'Killshot', 'Fugitive', 'Darkest', 'Jungle',
    'Forcefield', 'Thirteen', 'Brotherhood', 'Hardwired', 'Hellhole', 'Encounter', 'Silence', 'Speed', 'Duplicity', 'Undercover',
    'Genesis', 'Samurai', 'Smokescreen', 'Renegade', 'Greendale', 'Windfall', 'Motherland', 'Speed', 'Cleopatra', 'Blazing',
    'Ocean', 'Hitman', 'Doppelganger', 'Revelation', 'Alchemist', 'Escapee', 'Propaganda', 'Extinction', 'Resonance', 'Soulmate',
    'Faultline', 'Shotcaller', 'Distortion', 'Resurgence', 'Misfit', 'Skyfall', 'Fortress', 'Restraint', 'Burnout', 'Asylum',
    'Altered', 'Catalyst', 'Blacklist', 'Bloodmoon', 'Symmetry', 'Exterminator', 'Dangerous', 'Prometheus', 'Impulse', 'Poison',
    'Mindscape', 'Suburbicon', 'Sunburn', 'Valiant', 'Synergy', 'Stronghold', 'Terminator', 'Intuition', 'Uncharted', 'Vindicator',
    'Deadlock', 'Barricade', 'Threshold', 'Unhinged', 'Defender', 'Mindhunter', 'Insurgence', 'Murderer', 'Redemption', 'Hacksaw',
    'Celestial', 'Golem', 'Borderland', 'Faultline', 'Decoy', 'Guardian', 'Delirium', 'Crossroads', 'Sniper', 'Theory', 'Predator',
    'Inquisitor', 'Nemesis', 'Elixir', 'Breakaway', 'Daydream', 'Serendipity', 'Foxhound', 'Whisper', 'Aftershock', 'Firewatch',
    'Overlord', 'Flashpoint', 'Sidekick', 'Curfew', 'Paradox', 'Symbiosis', 'Blockbuster', 'Demolition', 'Deadweight', 'Quickfire',
    'Scavenger', 'Overkill', 'Firestorm', 'Martyr', 'Confluence', 'Moonbeam', 'Excalibur', 'Scavenger', 'Whitewash', 'Collapsing',
    'Underling', 'Counterstrike', 'Finale', 'Aftershock', 'Hellbent', 'Jettison', 'Macabre', 'Mindbender', 'Overdose', 'Fullforce'
]

# %%
# Getting all the unique movie names as a set of list
movieNameSetList = list(set(movieNameList))
# Assigning genres for the unique movie names in random
unqiue_genre_define_to_movies = {movie: random.choice(genreList) for movie in movieNameSetList}
# generating genres for all the 1200 rows
randomlyAssignedGenre = [unqiue_genre_define_to_movies[movie] for movie in movieNameList]

Genre_df = pd.DataFrame({
    'Name': movieNameList,
    'Genre': randomlyAssignedGenre
})

# %%
Genre_df
# Out:
#             Name     Genre
# 0        Boyhood   Western
# 1           Juno     Drama
# 2          Rocky     Drama
# 3           Rush  Thriller
# 4          Crash     Drama
# ...          ...       ...
# 1081    Jettison    Action
# 1082     Macabre  Periodic
# 1083  Mindbender    Comedy
# 1084    Overdose    Action
# 1085   Fullforce    Comedy
#
# [1086 rows x 2 columns]

# %%
Genre_df.to_csv('/content/sample_data/GenreTableData.csv', index=False)

# %% [markdown]
# *** Rating Table ***

# %%
ratingList = ["U", "PG", "12A", "15", "18"]

# %%
ID = []
for i in count:
    ID.append(i)

# %%
movieNameSetList = list(set(movieNameList))
unqiue_rating_define_to_movies = {movie: random.choice(ratingList) for movie in movieNameSetList}
randomlyAssignedRating = [unqiue_rating_define_to_movies[movie] for movie in movieNameList]

Rating_df = pd.DataFrame({
    'Id': ID,
    'Name': movieNameList,
    'Rating': randomlyAssignedRating
})

# %%
Rating_df
# Out:
#         Id        Name Rating
# 0        1     Boyhood     15
# 1        2        Juno     18
# 2        3       Rocky      U
# 3        4        Rush     15
# 4        5       Crash      U
# ...    ...         ...    ...
# 1081  1082    Jettison     PG
# 1082  1083     Macabre     15
# 1083  1084  Mindbender    12A
# 1084  1085    Overdose    12A
# 1085  1086   Fullforce    12A
#
# [1086 rows x 3 columns]

# %%
Rating_df.to_csv('/content/sample_data/RatingTableData.csv', index=False)

# %% [markdown]
# *** Budget Table ***

# %%
budget_floats = np.round(np.random.uniform(300000, 1e8, 1086), 2)
revenue_floats = np.round(np.random.uniform(10e8, 100e8, 1086), 2)
runtime_int = np.round(np.random.uniform(80, 200, 1086))

# %%
Budget_df = pd.DataFrame({
    'Budget': budget_floats,
    'Revenue': revenue_floats,
    'Runtime': runtime_int,
    'Id': ID,
})

# %%
Budget_df['Runtime'] = Budget_df['Runtime'].astype(int)
Budget_df['Revenue'] = Budget_df['Revenue'].astype(int)
Budget_df['Budget'] = Budget_df['Budget'].astype(int)

# %%
Budget_df
# Out:
#         Budget     Revenue  Runtime    Id
# 0     10684918  1258966088       89     1
# 1     40341159  1431770557      173     2
# 2     76389888  3707392702       95     3
# 3     30334635  5390133973       90     4
# 4     75084487  1579997311       96     5
# ...        ...         ...      ...   ...
# 1081  54729702  3472881955      168  1082
# 1082  93221122  7941806344      197  1083
# 1083    923340  2431265512      102  1084
# 1084  92777161  1286399795      150  1085
# 1085   4560937  3496108571      199  1086
#
# [1086 rows x 4 columns]

# %%
Budget_df.to_csv('/content/sample_data/BudgetTableData.csv', index=False)

# %% [markdown]
# *** Release Table ***

# %%
new_count = np.arange(1, 601)

# %%
releaseYear = np.arange(1910, 2024) #Interval
CriticReviewRank = ["Excellent", "Good", "Fair", "Poor"] #Ordinal

# %%
ID = []
for i in new_count:
  ID.append(i)

# %%
randomlyAssignedRank = {id:random.choice(CriticReviewRank) for id in ID}
randomlyAssignedReleaseYear = {id:random.choice(releaseYear) for id in ID}

# %%
Release_df = pd.DataFrame({
    'Id': ID,
    'Critic Rank': [randomlyAssignedRank[id] for id in ID],
    'Release Year': [randomlyAssignedReleaseYear[id] for id in ID]
})

# %%
Release_df
# Out:
#       Id Critic Rank  Release Year
# 0      1        Good          1991
# 1      2        Fair          1953
# 2      3        Fair          2022
# 3      4        Good          2023
# 4      5   Excellent          1938
# ..   ...         ...           ...
# 595  596        Good          1973
# 596  597        Fair          1964
# 597  598   Excellent          1938
# 598  599   Excellent          2005
# 599  600        Poor          2001
#
# [600 rows x 3 columns]

# %%
Release_df.to_csv('/content/sample_data/ReleaseTableData.csv', index=False)

# %% [markdown]
# *** Audience Table ***

# %%
new_count_1 = np.arange(1, 751)
audienceId = np.random.randint(1000, 1752, 751)  #Interval
numberOfTicketsBought = np.random.randint(1, 10, 751) #Ratio
satisfactionLevel = ["Very Unsatisfied", "Unsatisfied", "Neutral", "Satisfied", "Very Satisfied"] #Ordinal

# %%
ID = []
for i in new_count_1:
  ID.append(i)

# %%
randomlyAssignedNumberOfTicketsBought = {id : random.choice(numberOfTicketsBought) for id in ID}
randomlyAssignedSatisfactionLevel = {id : random.choice(satisfactionLevel) for id in ID}
randomlyAssignedAudienceId = {id : random.choice(audienceId) for id in ID}

# %%
Audience_df = pd.DataFrame({
    'Id': ID,
    'Audience Id': [randomlyAssignedAudienceId[id] for id in ID],
    'Satisfaction Level': [randomlyAssignedSatisfactionLevel[id] for id in ID],
    'Number Of Tickets Bought': [randomlyAssignedNumberOfTicketsBought[id] for id in ID]
})

# %%
Audience_df
# Out:
#       Id  Audience Id Satisfaction Level  Number Of Tickets Bought
# 0      1         1696          Satisfied                         8
# 1      2         1711            Neutral                         4
# 2      3         1420            Neutral                         6
# 3      4         1556          Satisfied                         6
# 4      5         1592            Neutral                         8
# ..   ...          ...                ...                       ...
# 745  746         1234            Neutral                         2
# 746  747         1334        Unsatisfied                         9
# 747  748         1333          Satisfied                         7
# 748  749         1476            Neutral                         4
# 749  750         1065     Very Satisfied                         7
#
# [750 rows x 4 columns]

# %%
Audience_df.to_csv('/content/sample_data/AudienceTableData.csv', index=False)
